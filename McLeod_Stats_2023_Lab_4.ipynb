# %% [markdown]
# <a href="https://colab.research.google.com/github/pmcleod10/Data_Sci/blob/main/McLeod_Stats_2023_Lab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stats Notebook Lab #4

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([1,2,3,4])

# %%
# population

# %%
np.sum(x)   # showing the sum of the array
# Out:
# 10

# %%
x.shape[0]    #
# Out:
# 4

# %%
np.sum(x)/x.shape[0]  # sum divided by the shape
# Out:
# 2.5

# %%
def mean(x):
    return np.sum(x)/x.shape[0]   # setting a "shortcut" for mean(x)

# %%
mean(x)
# Out:
# 2.5

# %%
x
# Out:
# array([1, 2, 3, 4])

# %%
x - mean(x)   # subtracting the mean of x from each number in the array
# Out:
# array([-1.5, -0.5,  0.5,  1.5])

# %%
(x - mean(x))**2    # squaring each number of the array
# Out:
# array([2.25, 0.25, 0.25, 2.25])

# %%
 def var(x):
    return mean((x - mean(x))**2)

# %%
def std(x):
    return np.sqrt(var(x))

# %%
mean(x)
# Out:
# 2.5

# %%
var(x)
# Out:
# 1.25

# %%
std(x)
# Out:
# 1.118033988749895

# %% [markdown]
# ### Random Number Generator

# %% [markdown]
# $y=mx+b$

# %%
m = 75                 # multiplier
b = 74                 # increment
n = 65537              # modulus

# %%
x = 58      # seed value

# %%
X = np.zeros(50000,) # giving X a value

# %%
x = (m * x + b) % n  # equation for number generator

# %%
for i in range(X.shape[0]):   # making x the number generator

    x = (m * x + b) % n
    
    X[i] = x

# %%
X
# Out:
# array([ 4189., 52101., 40966., ..., 26762., 41114.,  3385.])

# %%
X /= np.max(X)

# %%
plt.plot(X[:100],'.')

# %%
plt.hist(X);

# %%
plt.hist(X,100);

# %%
X
# Out:
# array([0.06392004, 0.7950103 , 0.62510109, ..., 0.40836194, 0.62735943,
#        0.05165179])

# %%
X
# Out:
# array([0.06392004, 0.7950103 , 0.62510109, ..., 0.40836194, 0.62735943,
#        0.05165179])

# %%
X
# Out:
# array([0.06392004, 0.7950103 , 0.62510109, ..., 0.40836194, 0.62735943,
#        0.05165179])

# %% [markdown]
# ### Random Numbers

# %%
X = np.random.random(50000,)

# %%
X
# Out:
# array([0.34474088, 0.78762853, 0.30594853, ..., 0.11177244, 0.28864228,
#        0.02404669])

# %%
plt.hist(X,100); # making a random plot with the number generator

# %%
np.random.random()
# Out:
# 0.34815725986360435

# %%
r = np.random.random()

# %%
r
# Out:
# 0.8351567964924608

# %%
r = np.random.randint(1,10)

# %%
r
# Out:
# 2

# %%
r = np.random.randint(0,3,size=(1))

# %%
r[0]
# Out:
# 2

# %%
game = ['rock', 'paper', 'scissors']   # using number generator to make a game

# %%
game[r[0]]
# Out:
# 'scissors'

# %%
p1 = np.random.randint(0,3,size=(1))[0]
p2 = np.random.randint(0,3,size=(1))[0]

# %%
p1,p2
# Out:
# (0, 0)

# %%
p1 = np.random.randint(0,3,size=(1))[0]
p2 = np.random.randint(0,3,size=(1))[0]
game[p1],game[p2]                             # picks randomly between 2 of the variables
# Out:
# ('rock', 'paper')

# %%
import numpy as np

# %%
np.random.randn()   # random integer
# Out:
# -0.42703814122938943

# %%
numbers  = np.random.randn(2,4)

# %%
numbers.shape      #
# Out:
# (2, 4)

# %%
numbers = numbers.reshape(-1)

# %%
numbers.shape
# Out:
# (8,)

# %%
# numbers= np.array([1,2,2,3,3,3,4,4,4,4])

# %%
numbers = np.random.randn(100000,)

# %%
numbers.shape
# Out:
# (100000,)

# %%
plt.hist(numbers,100);    # plotting random points

# %%
numbers = np.random.rand(1000000,)

# %%
plt.hist(numbers,100);

# %%
np.random.seed(12345)
data = np.random.randn(2, 100)

plt.figure(1, figsize=(9, 9))


plt.subplot(2,2,1)
plt.hist(data[0])

plt.subplot(2,2,2)
plt.scatter(data[0], data[1])

plt.subplot(2,2,3)
plt.plot(data[0], data[1])

plt.subplot(2,2,4)
plt.hist2d(data[0], data[1])

plt.show()           #making a bunch of different graphs at the same time

# %% [markdown]
# Normal Dist Data

# %%
x = 50*np.random.randn(10000)

# %%
plt.hist(x);    # a histogram with 10000 numbers normally distributed

# %%
x = np.random.rand(1000,)

# %%
plt.hist(x**2);

# %%
mu = 100  # mean of distribution
sigma = 15  # standard deviation of distribution
x = mu + sigma * np.random.randn(10000)

# %%
n,bins,patches = plt.hist(x)

# %%
bins
# Out:
# array([ 47.67401067,  58.75290006,  69.83178945,  80.91067884,
#         91.98956823, 103.06845762, 114.14734702, 125.22623641,
#        136.3051258 , 147.38401519, 158.46290458])

# %%
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(y)

# %%
num_bins = 50
n,bins,patches = plt.hist(x, num_bins, density=1)
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(bins,y)

# %%
def mean(x):
    return np.sum(x)/x.shape[0]

# %%
def var(x):
    return mean((x - mean(x))**2)

# %%
def std(x):
    return np.sqrt(var(x))

# %%
mean(x)
# Out:
# 100.08288406198832

# %%
std(x)
# Out:
# 14.975014354444243

# %% [markdown]
# # Normal Random Number Generator

# %%
#CDF PDF

# %%
x = np.linspace(-10,10,100)     # 
y = 2.71**(-x**2)
plt.plot(x,y)

# %% [markdown]
# $e^{-x^2}$

# %% [markdown]
# ![alt text](https://wikimedia.org/api/rest_v1/media/math/render/svg/4abaca87a10ecfa77b5a205056523706fe6c9c3f)

# %%
def normal_pdf(x,mu,sigma):
  
  return (1/(np.sqrt(2*np.pi*sigma**2)))*np.exp((-(x-mu)**2)/(2*sigma**2))

# %%
x = np.linspace(-6,6,1000)

# %%
mu = 0

# %%
sigma = 1

# %%
pdf = normal_pdf(x,mu,sigma) #Use Normal for demo, replace with custom function pdf

# %%
plt.plot(x,pdf,'.')
plt.plot(x,y,'g.')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-79-8c92baab425f> in <module>
#       1 plt.plot(x,pdf,'.')
# ----> 2 plt.plot(x,y,'g.')
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2759 @docstring.copy(Axes.plot)
#    2760 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
#    2763         is not None else {}), **kwargs)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     340
#     341         if x.shape[0] != y.shape[0]:
# --> 342             raise ValueError(f"x and y must have same first dimension, but "
#     343                              f"have shapes {x.shape} and {y.shape}")
#     344         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (1000,) and (100,)

# %%
def partial_sums(x):

  y = np.zeros(x.shape)
  
  for n in range(x.shape[0]):
    
    y[n] = np.sum(x[0:n])
    
  y = y / np.max(y)
    
  return y

# %%
cdf = partial_sums(pdf)

# %%
plt.plot(x,cdf,'.');

# %%
d_cdf = cdf[1:] - cdf[0:-1] #Demo to show that the diff of the cdf gives you back the pdf
plt.plot(x[1:],d_cdf,'.');  #Not required for sampling

# %%
plt.plot(cdf,x,'.');

# %%
def find_nearest(array, value):

  idx = np.argmin(np.abs(array - value))
  
  return idx

# %%
find_nearest(cdf, 0.1)
# Out:
# 393

# %%
x[393]
# Out:
# -1.2792792792792795

# %%
xr = np.random.random((10000,))

# %%
w = np.zeros(xr.shape[0])

for i in range(xr.shape[0]):
  
  w[i] = x[find_nearest(cdf, xr[i])]

# %%
w.shape
# Out:
# (10000,)

# %%
plt.hist(w,50);

# %%
num_bins = 50
n,bins,patches = plt.hist(w, num_bins, density=1)
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(bins,y)

# %% [markdown]
# # Random Color

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
z = np.random.randint(0,255,size=(1,1,3))

# %%
z
# Out:
# array([[[ 20, 233, 240]]])

# %%
z = np.random.randint(0,255,size=(10,10,3))

# %%
plt.imshow(z)

# %%
z = np.zeros((10,10,3))

# %%
z.shape
# Out:
# (10, 10, 3)

# %%
plt.imshow(z)

# %%
z = 0*np.ones((10,10,3))

# %%
plt.imshow(z)

# %%
z = 255*np.ones((10,10,3))

# %%
plt.imshow(z)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
z = np.ones((10,10,3))

z[:,:,0] = 1
z[:,:,1] = 0
z[:,:,2] = 0

plt.imshow(z)

# %%
z = np.ones((10,10,3))

z[:,:,0] = 0
z[:,:,1] = 1
z[:,:,2] = 0

plt.imshow(z)

# %%
z = np.ones((10,10,3))

z[:,:,0] = 0
z[:,:,1] = 0
z[:,:,2] = 1

plt.imshow(z)

# %%
plt.hist(np.random.randn(1000,)/6 + 1/2)
# Out:
# (array([ 22.,  75., 147., 259., 214., 163.,  82.,  27.,   9.,   2.]),
#  array([0.05479816, 0.16337509, 0.27195201, 0.38052893, 0.48910586,
#         0.59768278, 0.70625971, 0.81483663, 0.92341356, 1.03199048,
#         1.14056741]),
#  <a list of 10 Patch objects>)

# %%
for _ in range(100):
    z = np.ones((10,10,3))

    r = np.random.randn()/6 + 1/2
    g = np.random.randn()/6 + 1/2
    b = np.random.randn()/6 + 1/2

    print(r,g,b)

    z[:,:,0] = r
    z[:,:,1] = g
    z[:,:,2] = b

    plt.imshow(z);
# Out:
# 0.48876669811378975 0.3645447748208758 0.23699382656641066
# 0.5160230577806457 0.756004850948897 0.5631849262983825
# 0.6061575775238952 0.44461349547291984 0.6316154559589885
# 0.7011386380097219 0.439409364522479 0.47351285773077595
# 0.5918612975729618 0.2719674248312093 0.5385402073274934
# 0.7897000248886523 0.6689718066886502 0.34748288183689524
# 0.9570296408044947 0.6457374958310421 0.8293007399532942
# 0.2810913108593387 0.7431576759715688 0.43997859261607153
# 0.311639938214191 0.38703149481389865 0.5016861885138277
# 0.3406785919831863 0.3604425970785924 0.6082676875412035
# 0.43409517415031423 0.339683068552089 0.6041497869293433
# 0.5684863531363888 0.5384817761083962 0.45019433529610053
# 0.5489081834809642 0.37342886880059223 0.4881665799391679
# 0.5430048168986727 0.39327776464712705 0.5506431961291639
# 0.6680732834771796 0.30916920920472113 0.5575006655257392
# 0.60284368049259 0.5733740002207288 0.697364734887345
# 0.7501152986851667 0.7392661927328336 0.43883479905604994
# 0.5563339686246788 0.4684688538500111 0.6385324488819363
# 0.6278637694900991 0.49285560163150055 0.5159397524722341
# 0.3669747492650711 0.6705491883164044 0.7467647780437185
# 0.5969262615448526 0.5398613548008769 0.7082129908879623
# 0.2573663771033132 0.42690212323125987 0.4705302699928644
# 0.24030774437029617 0.4776367671387774 0.5544240991628611
# 0.2044059491485521 0.2693421146189494 0.49942213765469445
# 0.6843214257557506 0.12026651559361157 0.6444061256605292
# 0.5449067150162954 0.7241224403157276 0.382236912023004
# 0.2608109643828207 0.3894946356302379 0.2821096778994394
# 0.3364935945700277 0.6429410080079614 0.8089461907387031
# 0.9133546945930303 0.06425149654712181 0.36312153435425387
# 0.521040107758732 0.5292955060705484 0.9583649759959262
# 0.9775490239898459 0.8254512785399382 0.7726383827686156
# 0.7887323847523035 0.14663817421676084 0.301847037442315
# 0.6528311006816812 0.6017115994451175 0.3433903584191311
# 0.02804019066137431 0.44244395426954664 0.5314719429160716
# 0.2885448674660367 0.8982305815563929 0.043242260482429185
# 0.05513547019162168 0.2932994082269704 0.7349029777472016
# 0.6969829227366183 0.06455885954605511 0.42265391095555127
# 0.48742777760394607 0.16352346221856917 0.8408786782053013
# 0.9079549672373707 0.9367963365203206 0.055859127790370944
# 0.5647660695355936 0.5699658902713277 0.9003807122048232
# 0.6737171682621772 0.23948616620228114 0.05493057733273432
# 0.6878205797849727 0.4094695844845172 0.632796225625782

# %%
z1 = np.ones((10,10,3))
z1[:,:,0] = np.random.rand()
z1[:,:,1] = np.random.rand()
z1[:,:,2] = np.random.rand()

z2 = np.ones((10,10,3))
z2[:,:,0] = np.random.rand()
z2[:,:,1] = np.random.rand()
z2[:,:,2] = np.random.rand()

zavg = (z1+z2)/2

z1a = (z1+zavg)/2
z2a = (z2+zavg)/2

z3 = np.hstack((z1,z1a,zavg,z2a,z2))

plt.imshow(z3);
plt.show()

# %%
for i in range(100):
    
    z1 = np.ones((10,10,3))
    z1[:,:,0] = np.random.rand()
    z1[:,:,1] = np.random.rand()
    z1[:,:,2] = np.random.rand()

    z2 = np.ones((10,10,3))
    z2[:,:,0] = np.random.rand()
    z2[:,:,1] = np.random.rand()
    z2[:,:,2] = np.random.rand()

    zavg = (z1+z2)/2

    z1a = (z1+zavg)/2
    z2a = (z2+zavg)/2

    z3 = np.hstack((z1,z1a,zavg,z2a,z2))

    plt.imshow(z3);
    plt.show()

# %%
for i in range(100):
    
    z1 = np.ones((10,10,3))
    z2 = np.ones((10,10,3))

    r = np.random.rand()
    g = np.random.rand()
    b = np.random.rand()

    z1[:,:,0] = r
    z1[:,:,1] = g
    z1[:,:,2] = b
    
    z2[:,:,0] = 1-r
    z2[:,:,1] = 1-g
    z2[:,:,2] = 1-b

    z3 = np.hstack((z1,z2))

    plt.imshow(z3);
    plt.show()

# %% [markdown]
# https://lospec.com/palette-list

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib
import imageio
from PIL import Image

def get_colors_lospec(url):
    im = imageio.imread(url)
    rgb_list = (im/255)[0,:,0:3]
    float_list = list(np.linspace(0,1,len(rgb_list)))    
    cdict = dict()
    for num, col in enumerate(['red', 'green', 'blue']):
        col_list = [[float_list[i], rgb_list[i][num], rgb_list[i][num]] for i in range(len(float_list))]
        cdict[col] = col_list
    cmp = mcolors.LinearSegmentedColormap('my_cmp', segmentdata=cdict, N=256)
    return cmp

# %%
url = 'https://lospec.com/palette-list/agb-32x.png'

# %%
url = 'https://lospec.com/palette-list/agb-1x.png'

# %%
url = 'https://lospec.com/palette-list/moondrom-1x.png'

# %%
im = imageio.imread(url)

# %%
plt.imshow(im);

# %%
z = np.random.randint(0,255,size=(10,10))

# %%
plt.imshow(z, cmap=get_colors_lospec(url))
plt.colorbar();

# %%
x, y = np.mgrid[-5:5:0.05, -5:5:0.05]
z = np.sqrt(x**2 + y**2)

plt.imshow(z, cmap=get_colors_lospec(url));
plt.show()

# %%
x, y = np.mgrid[-5:5:0.05, -5:5:0.05]
z = np.sin(3*y)

plt.imshow(z, cmap=get_colors_lospec(url));
plt.show()

# %%
x, y = np.mgrid[-5:5:0.05, -5:5:0.05]
z = np.sin(3*y)*np.sin(3*x)

plt.imshow(z, cmap=get_colors_lospec(url));
plt.show()
